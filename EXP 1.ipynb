# %% [markdown]
# <a href="https://colab.research.google.com/github/Mysterio-maker/Exp-1-Basics-of-python/blob/main/EXP%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Read me
#
# Name-Amey Waghmare
# PRN- 25070123009
# Batch- A1
# Experiment 1

# %% [markdown]
# # EDA using Python
# ## Expet 1
#
# python basics

# %%
# First python program
print("Hello")
# Out:
# Hello

# %%
a= "Hello"
print(a)
# Out:
# Hello

# %%
#Many statements
print("hello"); print("pune"); print("india")
# Out:
# hello
# pune
# india

# %%
print("python is fun") print("Wow")
# Out:
#   File "/tmp/ipython-input-1439284626.py", line 1
#     print("python is fun") print("Wow")
#                            ^
# SyntaxError: invalid syntax

# %%
print("python is fun")
print("Wow")
# Out:
# python is fun
# Wow

# %%
print("Hello world", end=" ")
print("Welcome to Goa.")
# Out:
# Hello world Welcome to Goa.

# %%
# Case sensitive

a=4
A=7
print(a)
print(A)
# Out:
# 4
# 7

# %%
#Many values  to multiple variables

x, y, z = 'orange', 'yellow', 'red'

print(x)
print(y)
print(z)
# Out:
# orange
# yellow
# red

# %%
#Understanding data types

x = 10
y = 3.14
z = "python"
A = True
C= 3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# input from user
name= input("enter your name:")
print("hello", name)
# Out:
# enter your name:Batman
# hello Batman

# %%
# simple calculator

a= input("enter the first number:")
b= input("enter the second number:")
print(" what to do")

print("1 for addition")
print("2 for subtraction")
print("3 for multiplication")
print("4 for division")

choice= input("enter your choice:")
if choice == '1':
    print(int(a)+int(b))

elif  choice == '2':
    print(int(a)-int(b))

elif choice == '3':
    print(int(a)*int(b))

elif choice == '4':
        print(int(a)/int(b))

else:
        print("invalid choice")
# Out:
# enter the first number:7
# enter the second number:7
#  what to do
# 1 for addition
# 2 for subtraction
# 3 for multiplication
# 4 for division
# enter your choice:4
# 1.0

# %%
# Marks for 5 student

subject1=int(input("enter the marks of subject1:"))
subject2=int(input("enter the marks of subject2:"))
subject3=int(input("enter the marks of subject3:"))
subject4=int(input("enter the marks of subject4:"))
subject5=int(input("enter the marks of subject5:"))

choice= int(input("enter your choice:"))
if choice ==1:
    print(subject1+subject2+subject3+subject4+subject5)
elif choice ==2:
    print((subject1+subject2+subject3+subject4+subject5)/5)
else:
    print("invalid choice")2
# Out:
# enter the marks of subject1:20
# enter the marks of subject2:20
# enter the marks of subject3:20
# enter the marks of subject4:20
# enter the marks of subject5:20
# enter your choice:2
# 20.0

# %%
# Area of Circle and Rectangle

print("What to calculate")
print("1 for area of circle")
print("2 for area of rectangle")
choice= int(input("enter your choice:"))
if choice ==1:
    r=int(input("enter the radius:"))
    print(3.14*r*r)
elif choice ==2:
    l=int(input("enter the length:"))
    b=int(input("enter the breadth:"))
# Out:
# What to calculate
# 1 for area of circle
# 2 for area of rectangle
# enter your choice:1
# enter the radius:7
# 153.86

# %%
A= (3, 4, 5) + ( 4,5,6)
print(A)
# Out:
# (3, 4, 5, 4, 5, 6)
